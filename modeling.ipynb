# %% [markdown]
# # Modeling
#
# This is a file that was a test for plotting a scatterplot inside a surface in plotly.

# %%
import numpy as np
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers
pio.renderers.default = "notebook_connected"

# %%
def create_sun(size, clr, dist=0, opacity=1): 
    
    # Set up 100 points. First, do angles
    theta = np.linspace(0,2*np.pi,100)
    phi = np.linspace(0,np.pi,100)
    
    # Set up coordinates for points on the sphere
    x0 = dist + size * np.outer(np.cos(theta),np.sin(phi))
    y0 = size * np.outer(np.sin(theta),np.sin(phi))
    z0 = size * np.outer(np.ones(100),np.cos(phi))
    
    # Set up trace
    trace= go.Surface(x=x0, y=y0, z=z0, colorscale=[[0,clr], [1,clr]], opacity=opacity)
    trace.update(showscale=False)

    return trace

def create_photon(x, y, z, clr='white', wdth=2):
    trace = go.Scatter3d(x=x, y=y, z=z, line=dict(color=clr, width=wdth), marker=dict(size=0.1))

    return trace

# %%
sun = create_sun(200, '#ffff00', 0, 0.2) # Sun

# for photons, we will use scatter3d
photon = create_photon([10, 2, 3], [10, 20, 3], [10, 20, 3], clr='red')

fig = go.Figure(data = [sun, photon])

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="d3296d8a-9d6c-49c1-83fa-69dbc2a984bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d3296d8a-9d6c-49c1-83fa-69dbc2a984bf")) {                    Plotly.newPlot(                        "d3296d8a-9d6c-49c1-83fa-69dbc2a984bf",                        [{"colorscale":[[0,"#ffff00"],[1,"#ffff00"]],"opacity":0.2,"showscale":false,"x":[[0.0,6.34558669961353,12.684783931312902,19.011208660836534,25.318490714749853,31.600279194669977,37.85024887208204,44.06210655730813,50.22959743621585,56.34651136828593,62.40668913969741,68.40402866513374,74.33249113206551,80.18610708132275,85.95898241783433,91.64530434548209,97.23934722009375,102.73547831468126,108.12816349111951,113.41197277255415,118.58158581092808,123.63179724412103,128.55752193730785,133.35380010325832,138.0158022964224,142.5388342757726,146.91834173150667,151.14991487085166,155.22929285835136,159.15236810616642,162.91519041006714,166.51397092695427,169.94508598990288,173.20508075688775,176.2906726895164,179.1987548582672,181.92639907090367,184.4708588209163,186.82957205302134,189.0001637429337,190.98044828881478,192.7684317119884,194.36231366470832,195.76048924295574,196.9615506024416,197.96428837618654,198.76769289225084,199.3709551903885,199.77346783660158,199.97482553477502,199.97482553477502,199.77346783660158,199.3709551903885,198.76769289225084,197.96428837618654,196.9615506024416,195.76048924295574,194.36231366470832,192.7684317119884,190.98044828881478,189.0001637429337,186.82957205302137,184.47085882091628,181.9263990709037,179.19875485826716,176.2906726895164,173.20508075688772,169.94508598990285,166.51397092695427,162.91519041006717,159.1523681061664,155.22929285835136,151.14991487085166,146.91834173150667,142.53883427577256,138.01580229642238,133.35380010325832,128.55752193730788,123.63179724412103,118.58158581092808,113.41197277255417,108.1281634911195,102.73547831468126,97.23934722009375,91.6453043454821,85.95898241783428,80.18610708132272,74.33249113206551,68.40402866513378,62.40668913969739,56.34651136828593,50.229597436215855,44.06210655730816,37.85024887208201,31.600279194669977,25.318490714749874,19.011208660836488,12.684783931312879,6.3455866996135315,2.4492935982947064e-14],[0.0,6.3328109806115,12.659245357374926,18.972932947141757,25.26751640169747,31.53665760907233,37.77404407548285,43.97339528147797,50.12846900588974,56.23306761122093,62.28104428414066,68.26630922480433,74.18283577876589,80.02466650530792,85.78591917607963,91.46079269800201,97.04357295447693,102.5286385590181,107.9104665155109,113.18363777940117,118.34284271421369,123.38288643790622,128.29869405367523,133.0853157599468,137.73793183440728,142.251857487055,146.6225475773869,150.8456011909695,154.9167660707869,158.83194289890298,162.58718942412713,166.17872443152712,169.60293154979178,172.85636289261075,175.9357425304033,178.83796978890203,181.56012237126887,184.09945930060044,186.4534236798592,188.61964526645235,190.59594285886484,192.38032649294473,193.9709994456282,195.3663600440875,196.5650032784796,197.5657222166721,198.3675092195216,198.9695569554808,199.37125921351293,199.57221151349503,199.57221151349503,199.37125921351293,198.9695569554808,198.3675092195216,197.5657222166721,196.5650032784796,195.3663600440875,193.9709994456282,192.38032649294473,190.59594285886484,188.61964526645235,186.45342367985924,184.09945930060044,181.5601223712689,178.837969788902,175.9357425304033,172.85636289261072,169.60293154979175,166.17872443152712,162.58718942412716,158.83194289890295,154.9167660707869,150.8456011909695,146.62254757738694,142.251857487055,137.73793183440725,133.0853157599468,128.2986940536753,123.38288643790622,118.34284271421369,113.1836377794012,107.91046651551088,102.5286385590181,97.04357295447693,91.4607 ...
